# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера 3</h2>
#
# Обработка пропусков проведена. Теперь мы учитываем в анализе всех клиентов и все особенности их поведения. Помарки исправлены, и теперь работа выполнена хорошо. У тебя получился классный проект, молодец. Спасибо за оставленные комментарии по исправлениям. Успехов в дальнейших проектах :)
#
#
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера 2</h2>
#
# Привет еще раз. Спасибо, что доделал работу. Оформление комментариев по работе сохраняется. Только обозначим, что это вторая итерация.
#
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера </h2>
#
# Привет! Спасибо, что исправил задание:) Однако я опять не смог щапустить проект) Спишем это на нестыковку версий библиотек. С большой долей вероятности так и есть. Ты проделал большую работу над проектом, однако его еще можно улучшить. Будет здорово, если ты, надеюсь, не против, если я буду на ты, будешь отвечать на комментарии и участвовать в диалоге.
#
# Мои комментарии обозначены пометкой **Комментарий ревьюера**. Далее в файле ты сможешь найти их в похожих ячейках (если фон комментария <font color=green>зелёный</font> - всё сделано правильно. Рекомендации укажу таким же цветом; <font color=orange>оранжевый</font> - некритичные замечания. Если таких замечаний меньше трех - проект может быть принят без их отработки; <font color=red>красный</font> - нужно переделать). Не удаляй эти комментарии и постарайся учесть их в ходе выполнения данного проекта.
#
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера 0</h2>
#
# Привет! Спасибо, что прислал задание:) Меня зовут Слепцов Артем и я буду проверять твой проект) Ты проделал большую работу над проектом, однако я не могу запустить твой проект из-за ошибки в коде. Пожалуйста, посмотри, что пошло не так. Как исправишь, присылай проект снова :)
#
# </div>

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарий студента 0:</b>Артём, привет. Закомментировал обновление seaborn, теперь отрабатывается</div>

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарий студента:</b>Спасибо за комментарии, странно что не отрабатывается код с графиками, пришлось поменять используемую функцию</div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера 2</h2>
#
# Теперь код отрабатывает без помарок. Здорово, что ты его исправил.
#
# </div>

# %% [markdown]
# # Проектная работа - Определение перспективного тарифа для телеком компании

# %% [markdown]
# ### Содержание
# * [Введение](#intro)
# * [1. Предобработка данных](#chapter1)
#     * [1.1 Изучение общей информации](#section_1_1)
#         * [1.1.a Звонки](#section_1_1_a)
#         * [1.1.b Интернет](#section_1_1_b)
#         * [1.1.c Сообщения](#section_1_1_c)
#         * [1.1.d Тарифы](#section_1_1_d)
#         * [1.1.e Пользователи](#section_1_1_e)
#     * [1.2 Обработка пропущенных значений и типов данных](#section_1_2)
#     * [1.3 Подготовка данных](#section_1_3)
#         * [1.3.a Расчёт длительности звонков](#section_1_3_a)
#         * [1.3.b Расчёт кол-ва сообщений](#section_1_3_b)
#         * [1.3.c Расчёт использованного траффика](#section_1_3_c)
#         * [1.3.d Объединение данных](#section_1_3_d)
#         * [1.3.e Расчёт выручки](#section_1_3_e)
# * [2. Анализ данных](#chapter2)
#     * [Подсчёт потребления услуг по месяцам](#section_2_1)
#     * [Расчёт средних значений](#section_2_2)
#     * [Расчёт дисперсии и стандартного отклонения](#section_2_3)
#     * [Построение гиcтограмм](#section_2_4)
# * [3. Проверка гипотез](#chapter3)
# * [4. Общий вывод](#chapter4)

# %% [markdown]
# ## Введение <a class="anchor" id="intro"></a>

# %% [markdown]
# Клиентам предлагают два тарифных плана: «Смарт» и «Ультра». Чтобы скорректировать рекламный бюджет, коммерческий департамент хочет понять, какой тариф приносит больше денег.<br><br>
# Мы проведём предварительный анализ тарифов на небольшой выборке клиентов. В вашем распоряжении данные 500 пользователей «Мегалайна»: кто они, откуда, каким тарифом пользуются, сколько звонков и сообщений каждый отправил за 2018 год.</br> Нужно проанализировать поведение клиентов и сделать вывод — какой тариф лучше.<br><br>
# **Описание тарифов**<br>
# **Тариф «Смарт»**<br>
# Ежемесячная плата: 550 рублей<br>
# Включено 500 минут разговора, 50 сообщений и 15 Гб интернет-трафика<br>
# Стоимость услуг сверх тарифного пакета:<br>
# минута разговора: 3 рубля<br>
# сообщение: 3 рубля<br>
# 1 Гб интернет-трафика: 200 рублей<br>
# **Тариф «Ультра»**<br>
# Ежемесячная плата: 1950 рублей<br>
# Включено 3000 минут разговора, 1000 сообщений и 30 Гб интернет-трафика<br>
# Стоимость услуг сверх тарифного пакета:<br>
# минута разговора: 1 рубль<br>
# сообщение: 1 рубль<br>
# 1 Гб интернет-трафика: 150 рублей<br>
# <br><br>
# «Мегалайн» всегда округляет вверх значения минут и мегабайтов. Если пользователь проговорил всего 1 секунду, в тарифе засчитывается целая минута.
#
# **Описание данных**
# * Таблица users (информация о пользователях):
#     * user_id — уникальный идентификатор пользователя
#     * first_name — имя пользователя
#     * last_name — фамилия пользователя
#     * age — возраст пользователя (годы)
#     * reg_date — дата подключения тарифа (день, месяц, год)
#     * churn_date — дата прекращения пользования тарифом (если значение пропущено, то тариф ещё действовал на момент выгрузки данных)
#     * city — город проживания пользователя
#     * tariff — название тарифного плана
# * Таблица calls (информация о звонках):
#     * id — уникальный номер звонка
#     * call_date — дата звонка
#     * duration — длительность звонка в минутах
#     * user_id — идентификатор пользователя, сделавшего звонок
# * Таблица messages (информация о сообщениях):
#     * id — уникальный номер сообщения
#     * message_date — дата сообщения
#     * user_id — идентификатор пользователя, отправившего сообщение
# * Таблица internet (информация об интернет-сессиях):
#     * id — уникальный номер сессии
#     * mb_used — объём потраченного за сессию интернет-трафика (в мегабайтах)
#     * session_date — дата интернет-сессии
#     * user_id — идентификатор пользователя
# * Таблица tariffs (информация о тарифах):
#     * tariff_name — название тарифа
#     * rub_monthly_fee — ежемесячная абонентская плата в рублях
#     * minutes_included — количество минут разговора в месяц, включённых в абонентскую плату
#     * messages_included — количество сообщений в месяц, включённых в абонентскую плату
#     * mb_per_month_included — объём интернет-трафика, включённого в абонентскую плату (в мегабайтах)
#     * rub_per_minute — стоимость минуты разговора сверх тарифного пакета (например, если в тарифе 100 минут разговора в месяц, то со 101 минуты будет взиматься плата)
#     * rub_per_message — стоимость отправки сообщения сверх тарифного пакета
#     * rub_per_gb — стоимость дополнительного гигабайта интернет-трафика сверх тарифного пакета (1 гигабайт = 1024 мегабайта)

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера</h2>
#
# Вступление в работу очень важно. Так ты поясняешь то, чему она посвящена. План работы сделан круто. Также стоит уделить внимание и описанию тех данных, с которыми мы работаем.
#
# </div>

# %% [markdown]
# ## 1. Предобработка данных <a class="anchor" id="chapter1"></a>

# %% [markdown]
# Импортируем модули, необходимые для работы и загрузим наборы данных

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as st

sns.set()

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера</h2>
#
# Правильно, что весь импорт ты проводишь в первой ячейке работы. Так твой коллега, запускающий работу, будет в курсе используемых в ней библиотек и сможет при необходимости быстро настроить окружение.
#
# </div>

# %%
raw_calls = pd.read_csv('/datasets/calls.csv', parse_dates=['call_date'])
raw_internet = pd.read_csv('/datasets/internet.csv', parse_dates = ['session_date'], index_col=0)
raw_messages = pd.read_csv('/datasets/messages.csv', parse_dates = ['message_date'])
raw_tariffs = pd.read_csv('/datasets/tariffs.csv')
raw_users = pd.read_csv('/datasets/users.csv', parse_dates = ['churn_date'])

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера 2</h2>
#
# Круто, что ты исправил все проблем в данных уже на стадии их считывания 👍
#
# </div>

# %% [markdown]
# ### 1.1 Изучение общей информации <a class="anchor" id="section_1_1"></a>

# %% [markdown]
# #### 1.1.a Звонки <a class="anchor" id="section_1_1_a"></a>

# %%
raw_calls.sample(10)
# Out:
#               id  call_date  duration  user_id
# 192669  1472_482 2018-11-28     15.47     1472
# 57009   1144_380 2018-05-20      1.20     1144
# 95968   1244_223 2018-06-24     11.28     1244
# 127686  1327_261 2018-10-23      7.24     1327
# 117744   1303_12 2018-10-13      9.73     1303
# 86299   1217_164 2018-09-01      9.77     1217
# 181464  1453_656 2018-09-03      0.00     1453
# 136761    1349_9 2018-12-29     17.10     1349
# 178251  1443_136 2018-09-26      4.73     1443
# 155699  1384_525 2018-11-07      1.93     1384

# %%
raw_calls.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 202607 entries, 0 to 202606
# Data columns (total 4 columns):
# id           202607 non-null object
# call_date    202607 non-null datetime64[ns]
# duration     202607 non-null float64
# user_id      202607 non-null int64
# dtypes: datetime64[ns](1), float64(1), int64(1), object(1)
# memory usage: 6.2+ MB

# %%
raw_calls.duration.value_counts()
# Out:
# 0.00     39613
# 4.49       142
# 5.50       142
# 6.15       141
# 6.38       141
#          ...
# 27.02        1
# 26.19        1
# 25.34        1
# 27.13        1
# 24.28        1
# Name: duration, Length: 2871, dtype: int64

# %%
print(f'Звонков с длительностью 0.00: {39613*100/202607:.2f}% от общего числа' )
# Out:
# Звонков с длительностью 0.00: 19.55% от общего числа

# %%
raw_calls.describe()
# Out:
#             duration        user_id
# count  202607.000000  202607.000000
# mean        6.755887    1253.940619
# std         5.843365     144.722751
# min         0.000000    1000.000000
# 25%         1.300000    1126.000000
# 50%         6.000000    1260.000000
# 75%        10.700000    1379.000000
# max        38.000000    1499.000000

# %% [markdown]
#  - Нет пропущенных значений;
#  - Около 20 процентов звонков имеют длительность 0. <br>
#  К сожалению, неизвестно, по какому принципу включались в БД звонки: фиксируются ли пропущенные, или звонки с минимальной длительностью занесены с ошибкой.<br> Предположим второй вариант и, зная правила тарификации, переведём все 0 в 1, и округлим остальные значения в большую сторону.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера </h2>
#
# Исходя из описанной гипотезы звонки с нулевой длительностью будут обработаны правильным образом.
#
# </div>

# %% [markdown]
# #### 1.1.b Интернет <a class="anchor" id="section_1_1_b"></a>

# %%
raw_internet.sample(10)
# Out:
#               id  mb_used session_date  user_id
# 89289    1302_89   255.96   2018-05-04     1302
# 50457   1173_106   486.20   2018-07-08     1173
# 110754   1376_14   552.29   2018-09-29     1376
# 118413  1400_124   285.12   2018-12-08     1400
# 62357   1211_190   904.42   2018-11-13     1211
# 15471   1054_451     0.00   2018-08-20     1054
# 24901   1086_108   697.00   2018-05-08     1086
# 84629   1287_184   427.55   2018-12-20     1287
# 60611   1204_696   134.40   2018-03-07     1204
# 82612   1280_225   129.52   2018-11-10     1280

# %%
raw_internet.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 149396 entries, 0 to 149395
# Data columns (total 4 columns):
# id              149396 non-null object
# mb_used         149396 non-null float64
# session_date    149396 non-null datetime64[ns]
# user_id         149396 non-null int64
# dtypes: datetime64[ns](1), float64(1), int64(1), object(1)
# memory usage: 5.7+ MB

# %%
raw_internet.describe()
# Out:
#              mb_used        user_id
# count  149396.000000  149396.000000
# mean      370.192426    1252.099842
# std       278.300951     144.050823
# min         0.000000    1000.000000
# 25%       138.187500    1130.000000
# 50%       348.015000    1251.000000
# 75%       559.552500    1380.000000
# max      1724.830000    1499.000000

# %% [markdown]
# - Нет пропущенных значений;
# - Для колонки *mb_used* применим тот же принцип ,что и для звонков в предыдущем пункте:0->1 и округление в большую сторону<br>
# за сессию может потратиться несколько кб (например фоновая передача данных приложениями), которые при представлении с двумя знаками после запятой видны не будут.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера 2</h2>
#
# Ок, вполне реальная причина появления нулей в данных. Исходя из нее, мы можем обработать такие значения и заменить их на 1.
#
# </div>

# %% [markdown]
# ### 1.1.c Сообщения <a class="anchor" id="section_1_1_c"></a>

# %%
raw_messages.sample(10)
# Out:
#               id message_date  user_id
# 11421    1048_67   2018-10-09     1048
# 34750   1149_562   2018-07-29     1149
# 55014   1244_180   2018-12-23     1244
# 72116    1303_68   2018-08-29     1303
# 74562   1315_143   2018-10-25     1315
# 122     1000_122   2018-12-07     1000
# 9726    1039_382   2018-08-24     1039
# 109823  1440_764   2018-07-23     1440
# 29655    1130_30   2018-07-19     1130
# 92701   1382_162   2018-12-17     1382

# %%
raw_messages.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 123036 entries, 0 to 123035
# Data columns (total 3 columns):
# id              123036 non-null object
# message_date    123036 non-null datetime64[ns]
# user_id         123036 non-null int64
# dtypes: datetime64[ns](1), int64(1), object(1)
# memory usage: 2.8+ MB

# %%
raw_messages.describe()
# Out:
#              user_id
# count  123036.000000
# mean     1256.989410
# std       143.523967
# min      1000.000000
# 25%      1134.000000
# 50%      1271.000000
# 75%      1381.000000
# max      1499.000000

# %% [markdown]
# - Нет пропущенных значений;

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера</h2>
#
# Столбцы с датой в каждом случае у нас имеют тип данных object. Исправить это уже при считывании данных тебе поможет [данная статья](https://towardsdatascience.com/4-tricks-you-should-know-to-parse-date-columns-with-pandas-read-csv-27355bb2ad0e) о исправлении типов данных столбцов с датой уже при считывании таблицы.
#
# </div>

# %% [markdown]
# #### 1.1.d Тарифы <a class="anchor" id="section_1_1_d"></a>

# %%
raw_tariffs
# Out:
#    messages_included  mb_per_month_included  minutes_included  \
# 0                 50                  15360               500
# 1               1000                  30720              3000
#
#    rub_monthly_fee  rub_per_gb  rub_per_message  rub_per_minute tariff_name
# 0              550         200                3               3       smart
# 1             1950         150                1               1       ultra

# %% [markdown]
# Здесь имеем характеристики тарифов

# %% [markdown]
# #### 1.1.e Пользователи <a class="anchor" id="section_1_1_e"></a>

# %%
raw_users.head(10)
# Out:
#    user_id  age churn_date              city first_name  last_name  \
# 0     1000   52        NaT         Краснодар     Рафаил  Верещагин
# 1     1001   41        NaT            Москва       Иван       Ежов
# 2     1002   59        NaT       Стерлитамак    Евгений  Абрамович
# 3     1003   23        NaT            Москва      Белла   Белякова
# 4     1004   68        NaT       Новокузнецк    Татьяна   Авдеенко
# 5     1005   67        NaT  Набережные Челны   Афанасий     Горлов
# 6     1006   21        NaT         Ульяновск     Леонид   Ермолаев
# 7     1007   65        NaT            Москва        Юна   Березина
# 8     1008   63        NaT         Челябинск     Рустэм  Пономарёв
# 9     1009   24        NaT             Пермь   Василиса    Блинова
#
#      reg_date tariff
# 0  2018-05-25  ultra
# 1  2018-11-01  smart
# 2  2018-06-17  smart
# 3  2018-08-17  ultra
# 4  2018-05-14  ultra
# 5  2018-01-25  smart
# 6  2018-02-26  smart
# 7  2018-04-19  smart
# 8  2018-12-19  smart
# ...

# %%
raw_users.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 8 columns):
# user_id       500 non-null int64
# age           500 non-null int64
# churn_date    38 non-null datetime64[ns]
# city          500 non-null object
# first_name    500 non-null object
# last_name     500 non-null object
# reg_date      500 non-null object
# tariff        500 non-null object
# dtypes: datetime64[ns](1), int64(2), object(5)
# memory usage: 31.4+ KB

# %%
raw_users.loc[raw_users.tariff=='smart']['tariff'].count()
# Out:
# 351

# %%
diff = (raw_users.loc[raw_users.tariff=='smart']['tariff'].count()/raw_users.loc[raw_users.tariff=='ultra']['tariff'].count())*100-100

# %%
print(f'Пользователей тарифа Smart больше на {diff:.2f}%')
# Out:
# Пользователей тарифа Smart больше на 135.57%

# %%
raw_users[~(raw_users['churn_date'].isnull())]
# Out:
#      user_id  age churn_date              city  first_name   last_name  \
# 19      1019   63 2018-10-05             Томск     Игнатий     Круглов
# 20      1020   59 2018-12-18              Чита        Тала     Костина
# 34      1034   66 2018-11-21           Вологда   Святослав    Бондарев
# 50      1050   44 2018-10-03            Тюмень      Рузана    Аничкина
# 51      1051   37 2018-10-14            Москва    Кристина      Сомова
# 56      1056   73 2018-10-14           Иркутск    Радислав    Артемьев
# 62      1062   24 2018-12-09            Москва   Александр    Коршунов
# 63      1063   45 2018-12-11              Тула       Таира     Климова
# 64      1064   55 2018-12-26            Якутск      Динара     Алфеева
# 65      1065   53 2018-12-09            Москва        Роза    Игнатова
# 71      1071   20 2018-08-31              Омск      Гектор     Чумаков
# 90      1090   54 2018-12-03         Череповец   Екатерина   Астафьева
# ...

# %% [markdown]
# Пропущенные значения в колонке churn_date - означают пользователей, контракт которых не истёк на момент подготовки данных. При необходимости, можно обработать путём простановки какой-либо будущей даты, либо вывести выбывших пользователей в отдельный датасет, а из оставшегося убрать колонку с пустыми значениями.<br><br>
# - Колонку *reg_date* переведём в datetime

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера </h2>
#
# Подумай также о возможных причинах появления ошибок в данных, а также о том, являются ли они случайными или нет. Можно высказать предварительные варианты их обработки.
#
# Первый взгляд на таблицы выполнен.
#
# </div>

# %% [markdown]
# ### 1.2 Обработка пропущенных значений и типов данных <a class="anchor" id="section_1_2"></a>

# %% [markdown]
# <s>Переведём колонки ,содержащие даты, из object в datetime</s>

# %% [markdown]
# <s>raw_calls['call_date']=pd.to_datetime(raw_calls['call_date'])
# raw_internet['session_date']=pd.to_datetime(raw_internet['session_date'])
# raw_messages['message_date']=pd.to_datetime(raw_messages['message_date'])
# raw_users['reg_date']=pd.to_datetime(raw_users['reg_date'])
# raw_users['churn_date']=pd.to_datetime(raw_users['churn_date'])</s>

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарий студента:</b>Даты перевёл в datetime на этапе считывания</div>

# %% [markdown]
# Разделим колонки id там, где это применимо.

# %%
raw_calls['call_id']=raw_calls['id'].apply(lambda x: int(x.split('_')[-1]))
raw_messages['sms_id']=raw_calls['id'].apply(lambda x: int(x.split('_')[-1]))
raw_internet['session_id']=raw_internet['id'].apply(lambda x: int(x.split('_')[-1]))

# %%
raw_calls.sample()
# Out:
#              id  call_date  duration  user_id  call_id
# 71697  1178_457 2018-06-20     14.04     1178      457

# %% [markdown]
# Преобразуем 0 в 1 и округлим в большую сторону значения длительности звонков и использованных мегабайт траффика

# %%
raw_calls['duration'].where(raw_calls['duration']!=0, 1, inplace=True)
raw_calls['duration']= np.ceil(raw_calls['duration']).astype('int')
raw_calls['duration'].describe()
# Out:
# count    202607.000000
# mean          7.353714
# std           5.733230
# min           1.000000
# 25%           2.000000
# 50%           6.000000
# 75%          11.000000
# max          38.000000
# Name: duration, dtype: float64

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера </h2>
#
# Верно, что округление производится до суммирования. Это согласуется с тем, как оператор фиксирует выручку. Только лучше обойтись без apply и применить np.ceil напрямую: np.ceil(raw_calls['duration']). Так код отработает значительно быстрее.
#
# </div>

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарий студента:</b>Спасибо, заменил</div>

# %% [markdown]
# Тарификация идёт по гигабайтам, поэтому преообразуем данные соответсвующим образом

# %%
raw_internet['mb_used'].where(raw_internet['mb_used']!=0, 1, inplace=True)
raw_internet['mb_used']= np.ceil(raw_internet['mb_used']).astype('int')
raw_internet.describe()
# Out:
#              mb_used        user_id     session_id
# count  149396.000000  149396.000000  149396.000000
# mean      370.753280    1252.099842     205.811856
# std       278.212524     144.050823     157.267497
# min         1.000000    1000.000000       0.000000
# 25%       139.000000    1130.000000      78.000000
# 50%       349.000000    1251.000000     172.000000
# 75%       560.000000    1380.000000     302.000000
# max      1725.000000    1499.000000     833.000000

# %% [markdown]
# <div class="alert alert-danger">
# <h2> Комментарий ревьюера </h2>
#
# Исходя из какого предположения нулевой трафик округлен до единицы? Стоит подробно описывать ход своих мыслей. Какова возможная причина их появления - недозвоны или что-то другое?
#
# </div>

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарий студента:</b>Описывал на этапе обзора данных, расписал подробнее</div>

# %% [markdown]
# <div class="alert alert-danger">
# <h2> Комментарий ревьюера </h2>
#
# Округление до Гб стоит проводить после расчета ежемесячного использования данной услуги клиентами. Иначе сейчас любая сессия длиной хоть 1Кб станет равной 1Гб. Согласись, 6 порядков при округлении - это много.
#
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера 2</h2>
#
# Увидел. Теперь помарки выше устранены.
#
# </div>

# %% [markdown]
# ### 1.3 Подготовка данных <a class="anchor" id="section_1_3"></a>

# %% [markdown]
# Посчитаем для каждого пользователя:
# - количество сделанных звонков и израсходованных минут разговора по месяцам;
# - количество отправленных сообщений по месяцам;
# - объем израсходованного интернет-трафика по месяцам;
# - помесячную выручку с каждого пользователя (вычтите бесплатный лимит из суммарного количества звонков, сообщений и интернет-трафика; остаток умножьте на значение из тарифного плана; прибавьте абонентскую плату, соответствующую тарифному плану).

# %% [markdown]
# #### 1.3.a Посчитаем и выведем количество сделанных звонков и их продолжительность для каждого абонента <a class="anchor" id="section_1_3_a"></a>

# %%
raw_calls['month']=raw_calls['call_date'].dt.month

monthly_call_count = raw_calls.groupby(['user_id', 'month']).agg({'call_id':'count'})

# %%
monthly_call_count.columns = ['monthly_call_count']

# %%
monthly_call_count
# Out:
#                monthly_call_count
# user_id month
# 1000    5                      22
#         6                      43
#         7                      47
#         8                      52
#         9                      58
# ...                           ...
# 1498    10                     41
# 1499    9                       9
#         10                     68
#         11                     74
#         12                     69
#
# [3174 rows x 1 columns]

# %%
monthly_call_dur = raw_calls.groupby(['user_id', 'month']).agg({'duration':'sum'})

# %%
monthly_call_dur.columns = ['monthly_call_duration']

# %%
monthly_call_dur
# Out:
#                monthly_call_duration
# user_id month
# 1000    5                        164
#         6                        187
#         7                        346
#         8                        418
#         9                        478
# ...                              ...
# 1498    10                       258
# 1499    9                         71
#         10                       473
#         11                       624
#         12                       505
#
# [3174 rows x 1 columns]

# %% [markdown]
# #### 1.3.b Посчитаем и выведем количество сообщений в месяц для каждого абонента<a class="anchor" id="section_1_3_b"></a>

# %%
raw_messages['month']=raw_messages['message_date'].dt.month

monthly_sms = raw_messages.groupby(['user_id', 'month'])[['sms_id']].count()

# %%
monthly_sms.columns = ['monthly_sms']

# %%
monthly_sms
# Out:
#                monthly_sms
# user_id month
# 1000    5               22
#         6               60
#         7               75
#         8               81
#         9               57
# ...                    ...
# 1498    10              42
# 1499    9               11
#         10              48
#         11              59
#         12              66
#
# [2717 rows x 1 columns]

# %% [markdown]
# #### 1.3.c Посчитаем и выведем количество использованного траффика в месяц для каждого абонента <a class="anchor" id="section_1_3_c"></a>

# %%
raw_internet['month']=raw_internet['session_date'].dt.month

monthly_mb = raw_internet.groupby(['user_id', 'month'])[['mb_used']].sum()

# %%
monthly_mb.columns = ['monthly_mb']

# %%
monthly_mb
# Out:
#                monthly_mb
# user_id month
# 1000    5            2257
#         6           23262
#         7           14017
#         8           14072
#         9           14583
# ...                   ...
# 1498    10          20614
# 1499    9            1849
#         10          17824
#         11          17994
#         12          13082
#
# [3203 rows x 1 columns]

# %% [markdown]
# Тарификация происходит в Гб, поэтому добавим соответствующий столбец, с округлением в большую сторону

# %%
monthly_mb['monthly_gb'] = np.ceil(monthly_mb['monthly_mb']/1024).astype('int')

# %%
monthly_mb
# Out:
#                monthly_mb  monthly_gb
# user_id month
# 1000    5            2257           3
#         6           23262          23
#         7           14017          14
#         8           14072          14
#         9           14583          15
# ...                   ...         ...
# 1498    10          20614          21
# 1499    9            1849           2
#         10          17824          18
#         11          17994          18
#         12          13082          13
#
# [3203 rows x 2 columns]

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера </h2>
#
# Вот тут уже можно округлять трафик до Гб. Иначе такие нереальные показатели сильно влияют на расчеты выручки. Согласись, 10000 за услуги оператора - явный перебор.
#
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера </h2>
#
# Помесячные показатели рассчитаны. Данные подготовлены к дальнейшим расчетам.
#
# </div>

# %% [markdown]
# #### 1.3.d Объединим полученную информацию в единый датафрейм <a class="anchor" id="section_1_3_d"></a></br>
# Применим метод *join* c параметром *outer* чтобы учесть пользователей, которые, не используют какую-то функцию тарифа, используя при этом другие

# %%
user_data =(
    monthly_call_count
    .join(monthly_call_dur, how='outer')
    .join(monthly_mb, how='outer')
    .join(monthly_sms, how='outer'))

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера </h2>
#
# Да, именно внешнее соединение нам и нужно в данном случае. Иначе в таблицу не попадут клиенты, которые не пользовались одним из видов услуг оператора в течение конкретного месяца.
#
# </div>

# %%
user_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 3214 entries, (1000, 5) to (1499, 12)
# Data columns (total 5 columns):
# monthly_call_count       3174 non-null float64
# monthly_call_duration    3174 non-null float64
# monthly_mb               3203 non-null float64
# monthly_gb               3203 non-null float64
# monthly_sms              2717 non-null float64
# dtypes: float64(5)
# memory usage: 139.1 KB

# %% [markdown]
# <a id='the_destination'></a>Как и предполагалось, есть пользователи, не использующие весь спектр предоставляемых тарифами услуг, особенно это касается смс-сообщений. При объединении датафреймов это образует пропуски. <br>
# Так как имеем дело с переменными-счётчиками, уместно будет заполнить пропоски нулями.

# %%
user_data.fillna(0, inplace=True)

# %% [markdown]
# <div class="alert alert-danger">
# <h2> Комментарий ревьюера 2</h2>
#
# Все правильно, не все клиенты пользуются всеми услугами. Однако все же пропуски стоит обработать, т.к. неиспользование услуги также несет в себе информацию. Отсутствие использования услуги для нас также важно.
#
# </div>

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарий студента 2:</b>Да, тут у меня ход мысли был неправильный. Исправил</div>

# %%
user_data
# Out:
#                monthly_call_count  monthly_call_duration  monthly_mb  \
# user_id month
# 1000    5                    22.0                  164.0      2257.0
#         6                    43.0                  187.0     23262.0
#         7                    47.0                  346.0     14017.0
#         8                    52.0                  418.0     14072.0
#         9                    58.0                  478.0     14583.0
# ...                           ...                    ...         ...
# 1498    10                   41.0                  258.0     20614.0
# 1499    9                     9.0                   71.0      1849.0
#         10                   68.0                  473.0     17824.0
#         11                   74.0                  624.0     17994.0
#         12                   69.0                  505.0     13082.0
#
#                monthly_gb  monthly_sms
# user_id month
# 1000    5             3.0         22.0
# ...

# %% [markdown]
# Добавим информацию о тарифах и городах абонентов

# %%
raw_users.set_index('user_id', inplace=True)

# %%
user_data = user_data.join(raw_users[['tariff', 'city']], how='inner')

# %%
user_data.reset_index()
# Out:
#       user_id  month  monthly_call_count  monthly_call_duration  monthly_mb  \
# 0        1000      5                22.0                  164.0      2257.0
# 1        1000      6                43.0                  187.0     23262.0
# 2        1000      7                47.0                  346.0     14017.0
# 3        1000      8                52.0                  418.0     14072.0
# 4        1000      9                58.0                  478.0     14583.0
# ...       ...    ...                 ...                    ...         ...
# 3209     1498     10                41.0                  258.0     20614.0
# 3210     1499      9                 9.0                   71.0      1849.0
# 3211     1499     10                68.0                  473.0     17824.0
# 3212     1499     11                74.0                  624.0     17994.0
# 3213     1499     12                69.0                  505.0     13082.0
#
#       monthly_gb  monthly_sms tariff         city
# ...

# %%
user_data =( user_data.reset_index()
            .merge(raw_tariffs, left_on=['tariff'], right_on='tariff_name', how='inner'))

# %%
user_data.head()
# Out:
#    user_id  month  monthly_call_count  monthly_call_duration  monthly_mb  \
# 0     1000      5                22.0                  164.0      2257.0
# 1     1000      6                43.0                  187.0     23262.0
# 2     1000      7                47.0                  346.0     14017.0
# 3     1000      8                52.0                  418.0     14072.0
# 4     1000      9                58.0                  478.0     14583.0
#
#    monthly_gb  monthly_sms tariff       city  messages_included  \
# 0         3.0         22.0  ultra  Краснодар               1000
# 1        23.0         60.0  ultra  Краснодар               1000
# 2        14.0         75.0  ultra  Краснодар               1000
# 3        14.0         81.0  ultra  Краснодар               1000
# 4        15.0         57.0  ultra  Краснодар               1000
#
#    mb_per_month_included  minutes_included  rub_monthly_fee  rub_per_gb  \
# ...

# %%
user_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3214 entries, 0 to 3213
# Data columns (total 17 columns):
# user_id                  3214 non-null int64
# month                    3214 non-null int64
# monthly_call_count       3214 non-null float64
# monthly_call_duration    3214 non-null float64
# monthly_mb               3214 non-null float64
# monthly_gb               3214 non-null float64
# monthly_sms              3214 non-null float64
# tariff                   3214 non-null object
# city                     3214 non-null object
# messages_included        3214 non-null int64
# mb_per_month_included    3214 non-null int64
# minutes_included         3214 non-null int64
# rub_monthly_fee          3214 non-null int64
# rub_per_gb               3214 non-null int64
# rub_per_message          3214 non-null int64
# rub_per_minute           3214 non-null int64
# tariff_name              3214 non-null object
# dtypes: float64(5), int64(9), object(3)
# memory usage: 452.0+ KB

# %% [markdown]
# <div class="alert alert-danger">
# <h2> Комментарий ревьюера </h2>
#
# В таблице есть пропуски. Какова причина их появления и как их стоит обработать?
#
# </div>

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарий студента:</b>Добавил комментарий после <a href='#the_destination'>первого</a> применения info</div>

# %% [markdown]
# #### 1.3.e Посчитаем выручку, приносимую в месяц каждым абонентом  <a class="anchor" id="section_1_3_e"></a><br>
# Для расчёта напишем и применим функцию, в которой к базовой стоимости тарифа будет прибавляться рассчитанная стоимость дополнительных услуг, если они использовались

# %%
def revenue(row):
    base = row['rub_monthly_fee']
    if row['monthly_call_duration']>row['minutes_included']:
        call_revenue = (row['monthly_call_duration']-row['minutes_included'])*row['rub_per_minute']
    else:
        call_revenue = 0
    if row['monthly_gb']>row['mb_per_month_included']/1024:
        internet_revenue = (row['monthly_gb']-row['mb_per_month_included']/1024)*row['rub_per_gb']
    else:
        internet_revenue = 0
    if row['monthly_sms']>row['messages_included']:
        sms_revenue = (row['monthly_sms']-row['messages_included'])*row['rub_per_message']
    else:
        sms_revenue = 0
    return base + call_revenue + internet_revenue + sms_revenue

# %%
user_data['revenue']=user_data.apply(revenue, axis=1)

# %%
user_data.columns
# Out:
# Index(['user_id', 'month', 'monthly_call_count', 'monthly_call_duration',
#        'monthly_mb', 'monthly_gb', 'monthly_sms', 'tariff', 'city',
#        'messages_included', 'mb_per_month_included', 'minutes_included',
#        'rub_monthly_fee', 'rub_per_gb', 'rub_per_message', 'rub_per_minute',
#        'tariff_name', 'revenue'],
#       dtype='object')

# %%
user_data_final=user_data[['user_id', 'month', 'monthly_call_count', 'monthly_call_duration',
       'monthly_gb', 'monthly_sms', 'tariff', 'city', 'revenue']]

# %%
user_data_final.head()
# Out:
#    user_id  month  monthly_call_count  monthly_call_duration  monthly_gb  \
# 0     1000      5                22.0                  164.0         3.0
# 1     1000      6                43.0                  187.0        23.0
# 2     1000      7                47.0                  346.0        14.0
# 3     1000      8                52.0                  418.0        14.0
# 4     1000      9                58.0                  478.0        15.0
#
#    monthly_sms tariff       city  revenue
# 0         22.0  ultra  Краснодар   1950.0
# 1         60.0  ultra  Краснодар   1950.0
# 2         75.0  ultra  Краснодар   1950.0
# 3         81.0  ultra  Краснодар   1950.0
# 4         57.0  ultra  Краснодар   1950.0

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера </h2>
#
# Финальная таблица получена верным образом. Здорово, что она не содержит излишней информации в виде имени или фамилии клиента. Такая информация никак не поможет нам в анализе, поэтому хранить ее повторно не стоит.
#
# </div>

# %% [markdown]
# ## 2. Анализ данных <a class="anchor" id="chapter2"></a>

# %% [markdown]
# Опишем поведение клиентов оператора, исходя из выборки.

# %% [markdown]
# Для начала разделим данные на два набора, согласно тарифам пользователей

# %%
users_smart = user_data_final.query('tariff == "smart"')
users_smart.describe()
# Out:
#            user_id        month  monthly_call_count  monthly_call_duration  \
# count  2229.000000  2229.000000         2229.000000            2229.000000
# mean   1246.506505     8.346792           58.463437             429.450875
# std     146.119496     2.920316           25.939858             194.871174
# min    1001.000000     1.000000            0.000000               0.000000
# 25%    1121.000000     6.000000           40.000000             291.000000
# 50%    1239.000000     9.000000           60.000000             435.000000
# 75%    1376.000000    11.000000           76.000000             560.000000
# max    1499.000000    12.000000          198.000000            1471.000000
#
#         monthly_gb  monthly_sms      revenue
# count  2229.000000  2229.000000  2229.000000
# mean     16.365635    33.384029  1312.512337
# std       5.761298    28.227876   830.938122
# min       0.000000     0.000000   550.000000
# 25%      13.000000    10.000000   553.000000
# ...

# %%
users_ultra = user_data_final.query('tariff == "ultra"')
users_ultra.describe()
# Out:
#            user_id       month  monthly_call_count  monthly_call_duration  \
# count   985.000000  985.000000          985.000000             985.000000
# mean   1263.094416    8.250761           73.392893             540.779695
# std     140.694908    2.871762           43.916853             325.738740
# min    1000.000000    1.000000            0.000000               0.000000
# 25%    1143.000000    6.000000           41.000000             292.000000
# 50%    1277.000000    9.000000           74.000000             532.000000
# 75%    1381.000000   11.000000          104.000000             773.000000
# max    1495.000000   12.000000          244.000000            1727.000000
#
#        monthly_gb  monthly_sms      revenue
# count  985.000000   985.000000   985.000000
# mean    19.528934    49.363452  2071.065990
# std      9.862748    47.804457   378.802377
# min      0.000000     0.000000  1950.000000
# 25%     12.000000     6.000000  1950.000000
# ...

# %% [markdown]
# Сразу видим, что тарифом *smart* пользуется намного больше людей.
# <br> - Средняя и медианная выручка от тарифа Smart значительно превышают его базовую стоимость, что свидетельствует о высоком потреблении доп. услуг.
# <br> - Медианная выручка от тарифа Ultra соответствует его базовой стоимости, а вот средняя немного выше, что свидетельствует о том, что некоторые пользователи всё же пользуются доп услугами

# %% [markdown]
# #### 2.1 Посчитаем сколько минут разговора, сколько сообщений и какой объём интернет-трафика требовались пользователям каждого тарифа в месяц. <a class="anchor" id="section_2_1"></a>

# %%
user_smart_sum = users_smart.pivot_table(
                        index = ['month'],
                        values = ['monthly_call_duration', 'monthly_gb', 'monthly_sms'],
                        aggfunc= 'sum',
                        #margins = True, margins_name='Total',
                        )
user_smart_sum.columns = ['calls_sum','gb_sum','sms_sum']
user_smart_sum
# Out:
#        calls_sum  gb_sum  sms_sum
# month
# 1         7128.0   297.0    620.0
# 2        17766.0   688.0   1397.0
# 3        30841.0  1174.0   2453.0
# 4        42224.0  1528.0   3443.0
# 5        56175.0  2249.0   4762.0
# 6        66699.0  2622.0   5478.0
# 7        84277.0  3200.0   6784.0
# 8       101800.0  3945.0   7905.0
# 9       114421.0  4272.0   8746.0
# 10      128859.0  4975.0   9927.0
# 11      141448.0  5381.0  10768.0
# 12      165608.0  6148.0  12130.0

# %%
user_ultra_sum = users_ultra.pivot_table(
                        index = ['month'],
                        values = ['monthly_call_duration', 'monthly_gb', 'monthly_sms'],
                        aggfunc= 'sum',
                        #margins = True, margins_name='Total',
                        )
user_ultra_sum.columns = ['calls_sum','gb_sum','sms_sum']
user_ultra_sum
# Out:
#        calls_sum  gb_sum  sms_sum
# month
# 1         3968.0   120.0    304.0
# 2         7312.0   288.0    527.0
# 3        18614.0   655.0   1195.0
# 4        25854.0   935.0   1736.0
# 5        35166.0  1303.0   2536.0
# 6        41364.0  1593.0   3505.0
# 7        50987.0  1869.0   4536.0
# 8        56129.0  2101.0   5183.0
# 9        63669.0  2214.0   6013.0
# 10       70458.0  2471.0   7187.0
# 11       74478.0  2657.0   7476.0
# 12       84669.0  3030.0   8425.0

# %% [markdown]
# Представим информацию на графиках

# %%
plt.figure(figsize=(15, 5))
plt.subplots_adjust(wspace=0.3, hspace=0.3)
sns.set_style('darkgrid')
plt.suptitle('Объем потребления услуг в зависимости от месяца')
plt.subplot(2, 3, 1)
user_smart_sum['calls_sum'].plot()
user_ultra_sum['calls_sum'].plot()
plt.xlabel('звонки')
plt.legend(loc='upper left', labels = ['Smart', 'Ultra'] )

plt.subplot(2, 3, 2)
user_smart_sum['gb_sum'].plot()
user_ultra_sum['gb_sum'].plot()
plt.xlabel('траффик')
plt.legend(loc='upper left', labels = ['Smart', 'Ultra'] )

plt.subplot(2, 3, 3)
user_smart_sum['sms_sum'].plot()
user_ultra_sum['sms_sum'].plot()
plt.xlabel('сообщения')
plt.legend(loc='upper left', labels = ['Smart', 'Ultra'] )

# %% [markdown]
# <div class="alert alert-warning">
# <h2> Комментарий ревьюера </h2>
#
# Не стоит на одном рисунке показывать все услуги сразу. Все они измеряются в разных величинах (минуты, число штук, Мб).
#
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера 2</h2>
#
# Вынести каждую услугу на свой рисунок - верное решение.
#
# </div>

# %% [markdown]
# Видим, что потребление услуг растёт в течение года, но это скорее связано с возрастанием числа пользователей тарифа. Проверим

# %%
users_ultra.groupby('month')[['user_id']].count()
# Out:
#        user_id
# month
# 1            9
# 2           24
# 3           37
# 4           55
# 5           67
# 6           84
# 7           91
# 8          107
# 9          115
# 10         123
# 11         134
# 12         139

# %%
users_smart.groupby('month')[['user_id']].count()
# Out:
#        user_id
# month
# 1           34
# 2           58
# 3           77
# 4          112
# 5          141
# 6          164
# 7          201
# 8          235
# 9          260
# 10         294
# 11         316
# 12         337

# %% [markdown]
# Предположение подтвердилось и тариф Smart пользуется большей популярностью

# %% [markdown]
# #### 2.2 Рассчитаем средние значения <a class="anchor" id="section_2_2"></a>

# %%
user_smart_mean = users_smart.pivot_table(
                        index = ['month'],
                        values = ['monthly_call_duration', 'monthly_gb', 'monthly_sms'],
                        aggfunc= 'mean',
                        margins = True, margins_name='Yearly',
                        )
user_smart_mean.columns = ['calls_mean','gb_mean','sms_mean']
user_smart_mean

print(f'''Среднемесячная длительность звонков абонента тарифа Smart:
{users_smart.monthly_call_duration.mean():2.2f}
Среднемесячная длительность звонков абонента тарифа Ultra:
{users_ultra.monthly_call_duration.mean():2.2f}
Среднемесячное количество потраченного траффика абонента тарифа Smart:
{users_smart.monthly_gb.mean():2.2f}
Среднемесячное количество потраченного траффика абонента тарифа Ultra:
{users_ultra.monthly_gb.mean():2.2f}
Среднемесячное количество отправленных смс абонента тарифа Smart:
{users_smart.monthly_sms.mean():2.2f}
Среднемесячное количество отправленных смс абонента тарифа Ultra:
{users_ultra.monthly_sms.mean():2.2f}
''')
# Out:
# Среднемесячная длительность звонков абонента тарифа Smart:
# 429.45
# Среднемесячная длительность звонков абонента тарифа Ultra:
# 540.78
# Среднемесячное количество потраченного траффика абонента тарифа Smart:
# 16.37
# Среднемесячное количество потраченного траффика абонента тарифа Ultra:
# 19.53
# Среднемесячное количество отправленных смс абонента тарифа Smart:
# 33.38
# Среднемесячное количество отправленных смс абонента тарифа Ultra:
# 49.36

# %%
raw_tariffs
# Out:
#    messages_included  mb_per_month_included  minutes_included  \
# 0                 50                  15360               500
# 1               1000                  30720              3000
#
#    rub_monthly_fee  rub_per_gb  rub_per_message  rub_per_minute tariff_name
# 0              550         200                3               3       smart
# 1             1950         150                1               1       ultra

# %% [markdown]
# Пользователи тарифа Ultra в среднем укладываются во все лимиты, установленные тарифом.
# Пользователи тарифа Smart укладываются в лимит на сообщения и звонки, но превышают лимит на траффик

# %% [markdown]
# #### 2.3 Посчитаем дисперсию и стандартное отклонение <a class="anchor" id="section_2_3"></a>

# %%
np.var(users_ultra.monthly_sms)
# Out:
# 2282.9460753948824

# %%
print(f'''Дисперсия длительности звонков абонента тарифа Smart:
{np.var(users_smart.monthly_call_duration, ddof=1):2.2f}
Дисперсия звонков абонента тарифа Ultra:
{np.var(users_ultra.monthly_call_duration, ddof=1):2.2f}
Дисперсия потраченного траффика абонента тарифа Smart:
{np.var(users_smart.monthly_gb, ddof=1):2.2f}
Дисперсия потраченного траффика абонента тарифа Ultra:
{np.var(users_ultra.monthly_gb, ddof=1):2.2f}
Дисперсия отправленных смс абонента тарифа Smart:
{np.var(users_smart.monthly_sms, ddof=1):2.2f}
Дисперсия отправленных смс абонента тарифа Ultra:
{np.var(users_ultra.monthly_sms, ddof=1):2.2f}
''')
# Out:
# Дисперсия длительности звонков абонента тарифа Smart:
# 37974.77
# Дисперсия звонков абонента тарифа Ultra:
# 106105.73
# Дисперсия потраченного траффика абонента тарифа Smart:
# 33.19
# Дисперсия потраченного траффика абонента тарифа Ultra:
# 97.27
# Дисперсия отправленных смс абонента тарифа Smart:
# 796.81
# Дисперсия отправленных смс абонента тарифа Ultra:
# 2285.27

# %%
print(f'''Стандартное отклонение длительности звонков абонента тарифа Smart:
{np.std(users_smart.monthly_call_duration, ddof=1):2.2f}
Стандартное отклонение звонков абонента тарифа Ultra:
{np.std(users_ultra.monthly_call_duration, ddof=1):2.2f}
Стандартное отклонение потраченного траффика абонента тарифа Smart:
{np.std(users_smart.monthly_gb, ddof=1):2.2f}
Стандартное отклонение потраченного траффика абонента тарифа Ultra:
{np.std(users_ultra.monthly_gb, ddof=1):2.2f}
Стандартное отклонение отправленных смс абонента тарифа Smart:
{np.std(users_smart.monthly_sms, ddof=1):2.2f}
Стандартное отклонение отправленных смс абонента тарифа Ultra:
{np.std(users_ultra.monthly_sms, ddof=1):2.2f}
''')
# Out:
# Стандартное отклонение длительности звонков абонента тарифа Smart:
# 194.87
# Стандартное отклонение звонков абонента тарифа Ultra:
# 325.74
# Стандартное отклонение потраченного траффика абонента тарифа Smart:
# 5.76
# Стандартное отклонение потраченного траффика абонента тарифа Ultra:
# 9.86
# Стандартное отклонение отправленных смс абонента тарифа Smart:
# 28.23
# Стандартное отклонение отправленных смс абонента тарифа Ultra:
# 47.80

# %% [markdown]
# Выведем информацию в виде таблицы

# %%
stat_func = ('mean', np.var, np.std)

# %%
stats_table = user_data.pivot_table(
    index=['tariff'],
    values=['monthly_call_duration', 'monthly_sms', 'monthly_gb'],
    aggfunc={'monthly_call_duration': stat_func,
             'monthly_sms': stat_func,
             'monthly_gb': stat_func}
)

stats_table.columns = ['duration_mean', 'duration_stdev', 'duration_variance',
                            'gb_used_mean', 'gb_used_stdev', 'gb_used_variance',
                            'sms_mean', 'sms_stdev', 'sms_variance']
pd.options.display.float_format = '{:,.2f}'.format
stats_table
# Out:
#         duration_mean  duration_stdev  duration_variance  gb_used_mean  \
# tariff
# smart          429.45          194.87          37,974.77         16.37
# ultra          540.78          325.74         106,105.73         19.53
#
#         gb_used_stdev  gb_used_variance  sms_mean  sms_stdev  sms_variance
# tariff
# smart            5.76             33.19     33.38      28.23        796.81
# ultra            9.86             97.27     49.36      47.80      2,285.27

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера </h2>
#
# Будет здорово, если все стат. показатели ты соберешь в единую таблицу. Так нам будет куда проще анализировать их и сравинвать тарифв между собой.
#
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера 2</h2>
#
# Круто, что ты работаешь не только с желтыми и красными комментариями, но даже и с зелеными.
#
# </div>

# %% [markdown]
# #### 2.4 Теперь представим информацию о длительности звонков, отосланных сообщениях,использованном трафике и выручке в виде гистограмм.
#  <a class="anchor" id="section_2_4"></a>
#  В качестве доп информации на графики добавим вериткальные линии для обозначения лимита тарифа на услугу (за исключением лимита на сообщения для тарифа Ultra - ни один абонент его не превысил).

# %%
plt.figure(figsize=(15, 10))
plt.subplots_adjust(wspace=0.3, hspace=0.3)
sns.set_style('whitegrid')

plt.subplot(2, 2, 1)
call1 = sns.distplot(users_smart.loc[users_smart['monthly_call_duration'].notnull()]['monthly_call_duration'],
             label='Тариф Smart',
             color='red')
call1.set_xlim(0, 2000)
call2 = sns.distplot(users_ultra.loc[users_ultra['monthly_call_duration'].notnull()]['monthly_call_duration'],
             label='Тариф Ultra',
             color='blue')
call2.set_xlim(0, 2000)
plt.axvline(500, linewidth=2, color = 'red')
plt.axvline(1000, linewidth=2, color = 'blue')

plt.title('Распределение потраченных минут\nв зависимости от тарифа')
plt.xlabel('Кол-во минут')
plt.ylabel('Плотность распределения звонков')
plt.legend(loc='upper right')

plt.subplot(2, 2, 2)
gb1 = sns.distplot(users_smart.loc[users_smart['monthly_gb'].notnull()]['monthly_gb'],
             label='Тариф Smart',
             color='red')
gb1.set_xlim(0, 60)
gb2 = sns.distplot(users_ultra.loc[users_ultra['monthly_gb'].notnull()]['monthly_gb'],
             label='Тариф УЛЬТРА',
             color='blue')
gb2.set_xlim(0, 60)
plt.axvline(15, linewidth=2, color = 'red')
plt.axvline(30, linewidth=2, color = 'blue')

plt.title('Распределение потраченного трафика в Гб \n в зависимости от тарифа')
plt.xlabel('Кол-во Гб')
plt.ylabel('Плотность распределения')
plt.legend(loc='upper right')

plt.subplot(2, 2, 3)
sms1=sns.distplot(users_smart.loc[users_smart['monthly_sms'].notnull()]['monthly_sms'],
                             label='Тариф Smart',
                             color='red',
                     hist_kws={'range': [0,300]})
sms1.set_xlim(0, 300)
sms2=sns.distplot(users_ultra.loc[users_ultra['monthly_sms'].notnull()]['monthly_sms'],
                             label='Тариф УЛЬТРА',
                             color='blue',
                            hist_kws={'range': [0,300]})
sms2.set_xlim(0, 300)
plt.axvline(50, linewidth=2, color = 'red')

plt.title('Распределение отосланных SMS \n в зависимости от тарифа')
plt.xlabel('Кол-во SMS')
plt.ylabel('Плотность распределения')
plt.legend(loc='upper right')

plt.subplot(2, 2, 4)

revplot= sns.barplot(data=user_data_final,
                     x='tariff',
                     y=user_data_final.revenue,
                     estimator=sum,
                     palette = 'Reds' )
for p in revplot.patches:
    revplot.annotate(format(p.get_height(), '.1f'), 
                   (p.get_x() + p.get_width() / 2., p.get_height()), 
                   ha = 'center', va = 'center', 
                   xytext = (0, 9), 
                   textcoords = 'offset points') 
plt.title('Распределение значений выручки \n в зависимости от тарифа')
plt.xlabel('Тариф')
plt.ylabel('Суммарная выручка')
# Out:
# Text(0, 0.5, 'Суммарная выручка')

# %%
print(f'Выручка от тарифа Smart на {(users_smart.revenue.sum()/users_ultra.revenue.sum())*100-100:2.2f}% больше')
# Out:
# Выручка от тарифа Smart на 43.41% больше

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера </h2>
#
# Графики сделаны классно 👍 Однак код при перезапуске на них падает. Проверь еще раз, перезапусти проект на сервере.
#
# Посмотри на результаты после изменения способа  округления трафика. Значения по выручке, а также по трафику должны стать более реальными.
#
# </div>

# %% [markdown]
# - Пользователи тарифа Smart в среднем расходуют меньше минут, сообщений и траффик, при этом для пользователей тарифа Ultra больше разброс вокруг средних значений.
# - Большая часть пользователей тарифа Smart превышает установленные лимиты на длительность звонков и интернет-траффик. Имея численное превосходство пользователей тарифа Smart в выборке и более высокую стоимость доп. услуг, получаем более высокую суммарную выручку
# - В обоих тарифах пользователи часто не пользуются смс вообще, либо очень редко

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера </h2>
#
# Базовые статистические параметры получены. Приведены все необходимые графики. Здорово, что графики для одинаковых услуг тарифов приведены на одном рисунке. Так удобнее сравнивать тарифы.
#
# </div>

# %% [markdown]
# ## 3. Проверка гипотез <a class="anchor" id="chapter3"></a>

# %% [markdown]
# ### 3.1 Cредняя выручка с пользователей тарифов «Ультра» и «Смарт» различается;

# %% [markdown]
# Нулевой гипотезой в данном случае будет: средняя выручка не отличается между тарифами

# %%
from scipy import stats as st

revenue_1 = users_smart.revenue
revenue_2 = users_ultra.revenue

alpha = .01 # критический уровень статистической значимости
            # если p-value окажется меньше него - отвергнем гипотезу
            # значительная разница между средними значениями была видна уже при применении метода describe,
            # также её показал график. Можем выбрать минимальный уровень

results = st.ttest_ind(
    revenue_1, 
    revenue_2,
    equal_var=False)

print('p-значение:', results.pvalue)

if (results.pvalue < alpha):
    print("Отвергаем нулевую гипотезу")
else:
    print("Не получилось отвергнуть нулевую гипотезу")
# Out:
# p-значение: 1.2496710269965528e-233
# Отвергаем нулевую гипотезу

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера </h2>
#
# Гипотезы сформулированы и проверены верно. Посмотри на результаты тестирования после исправлени я помарки с округлением.
#
# </div>

# %% [markdown]
# ### 3.2 Cредняя выручка пользователей из Москвы отличается от выручки пользователей из других регионов;

# %% [markdown]
# Нулевая гипотеза: средняя выручка от пользователей из Москвы не отличается от выручки от пользователей других регионов
# Предварительно проверим равенство дисперсий, используя функцию levene, пакета scipy.stats

# %%
np.var((user_data.query('city =="Москва"')['revenue']), ddof=1)
# Out:
# 567332.0773309008

# %%
np.var((user_data.query('city !="Москва"')['revenue']), ddof=1)
# Out:
# 663465.6530958337

# %%
st.levene(user_data.query('city =="Москва"')['revenue'], user_data.query('city!="Москва"')['revenue'], center='mean')
# Out:
# LeveneResult(statistic=4.437759885380359, pvalue=0.03522971048174859)

# %% [markdown]
# Для данного метода проверки `pvalue`<0.05 означает, что нулевая гипотеза о равенстве дисперсий отвергается

# %%
moscow_users = user_data.query('city =="Москва"')['revenue']
other_users = user_data.query('city!="Москва"')['revenue']

alpha = .05
#выбран базовый критический уровень значимости

results = st.ttest_ind(
    moscow_users,
    other_users,
    equal_var=False)

print('p-значение:', results.pvalue)

if (results.pvalue < alpha):
    print("Отвергаем нулевую гипотезу")
else:
    print("Не получилось отвергнуть нулевую гипотезу")
# Out:
# p-значение: 0.5602596027403448
# Не получилось отвергнуть нулевую гипотезу

# %% [markdown]
# <div class="alert alert-danger">
# <h2> Комментарий ревьюера </h2>
#
# Прежде чем произвести проверку гипотезы через T-критерий Стьюдента произведи проверку дисперсии выборок, чтобы понять с каким параметром использовать метод проверки. Параметр equal_var ты уточнил, однако не совсем ясна причина, по которой мы должны использовать False.
#
# </div>

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарий студента:</b>Добавил проверку равенства дисперсий</div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера 2</h2>
#
# Молодец, что знаешь о методе проверки равенства дисперсий при помощи стат. тестов. Уточнение параметра equal_var позволяет нам увеличить точность проводимых тестов.
#
# </div>

# %% [markdown]
# ## 4. Вывод <a class="anchor" id="chapter4"></a>

# %% [markdown]
# За исключением неверно выбранного формата представления длительности звонка и расхода траффика за сессию, данные не имели ошибок. <br>
# Были рассчитаны месячный объем потребления услуг каждым абонентом и выручка, затем
# был проведён статистический анализ данных и изучено поведение пользователей двух тарифов.
# <br><br>Проверены гипотезы о равенстве средних выручек от двух тарифов и отличии средней выручки от московских пользователей от пользователей других городов:
#
# 1. Тариф Smart приносит на 30% больше выручки: 2.93 млн. руб. против 2.04 млн. руб. за счёт более активного использования его клиентами услугами сверх тарифа. Особенно это касается интернет-траффика.
# 2. Московские абоненты не отличаются значительно от абонентов из других городов в плане приносимой выручки

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера </h2>
#
# Выводы описаны. Приведены ответы на главные вопросы проекта. В выводах можно приводить полученные ранее значения. Также можно расписать все, что было сделано в ходе проведения работы. Скорректируй выводы после исправления помарок.
#
# </div>

# %% [markdown]
# <div class="alert alert-warning">
# <h2> Комментарий ревьюера </h2>
#
# Если тебе нравится тема визуализации, то можешь изучить другие методы библиотеки seaborn. Она позволяет строить довольно презентабельные графики.
#
# Ты проделал большую работу, молодец! Критических замечаний немного. Однако с ними важно поработать. Они крайне сильно влияют на результаты анализа. Также есть достаточное число желтых комментариев. Думаю, исправить их тебе не составит труда. Жду твою работу :)
#
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера 2</h2>
#
# Молодец, что поработал со всеми помарками. Однако остался один момент, который следует доработать. Как исправишь отмеченную помарку, присылай работу снова. Постараюсь допроверить как можно быстрее, т.к. исправлений осталось совсем немного :)
#
# </div>
